# %% [markdown]
# # Gemma

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name="google/gemma-2b"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# Downloading shards: 100%|██████████| 4/4 [05:25<00:00, 81.37s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [01:29<00:00, 22.26s/it]

# %%
input_text = "How to change file permissions in Unix?"
input_ids = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**input_ids, max_new_tokens=100,repetition_penalty=1.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 4
#       1 input_text = "How to change file permissions in Unix?"
#       2 input_ids = tokenizer(input_text, return_tensors="pt")
# ----> 4 outputs = model.generate(**input_ids, max_new_tokens=100,repetition_penalty=1.5)
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/transformers/generation/utils.py:1736, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1728     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1729         input_ids=input_ids,
#    1730         expand_size=generation_config.num_return_sequences,
#    1731         is_encoder_decoder=self.config.is_encoder_decoder,
#    1732         **model_kwargs,
#    1733     )
#    1735     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1736     result = self._sample(
#    1737         input_ids,
#    1738         logits_processor=prepared_logits_processor,
#    1739         logits_warper=prepared_logits_warper,
#    1740         stopping_criteria=prepared_stopping_criteria,
#    1741         generation_config=generation_config,
#    1742         synced_gpus=synced_gpus,
#    1743         streamer=streamer,
#    1744         **model_kwargs,
#    1745     )
#    1747 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    1748     # 11. prepare logits warper
#    1749     prepared_logits_warper = (
#    1750         self._get_logits_warper(generation_config) if generation_config.do_sample else None
#    1751     )
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/transformers/generation/utils.py:2375, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2372 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2374 # forward pass to get next token
# -> 2375 outputs = self(
#    2376     **model_inputs,
#    2377     return_dict=True,
#    2378     output_attentions=output_attentions,
#    2379     output_hidden_states=output_hidden_states,
#    2380 )
#    2382 if synced_gpus and this_peer_finished:
#    2383     continue  # don't waste resources running the code we don't need
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/transformers/models/gemma/modeling_gemma.py:1098, in GemmaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1095 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1097 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1098 outputs = self.model(
#    1099     input_ids=input_ids,
#    1100     attention_mask=attention_mask,
#    1101     position_ids=position_ids,
#    1102     past_key_values=past_key_values,
#    1103     inputs_embeds=inputs_embeds,
#    1104     use_cache=use_cache,
#    1105     output_attentions=output_attentions,
#    1106     output_hidden_states=output_hidden_states,
#    1107     return_dict=return_dict,
#    1108     cache_position=cache_position,
#    1109 )
#    1111 hidden_states = outputs[0]
#    1112 logits = self.lm_head(hidden_states)
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/transformers/models/gemma/modeling_gemma.py:902, in GemmaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     891     layer_outputs = self._gradient_checkpointing_func(
#     892         decoder_layer.__call__,
#     893         hidden_states,
#    (...)
#     899         cache_position,
#     900     )
#     901 else:
# --> 902     layer_outputs = decoder_layer(
#     903         hidden_states,
#     904         attention_mask=causal_mask,
#     905         position_ids=position_ids,
#     906         past_key_value=past_key_values,
#     907         output_attentions=output_attentions,
#     908         use_cache=use_cache,
#     909         cache_position=cache_position,
#     910     )
#     912 hidden_states = layer_outputs[0]
#     914 if use_cache:
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/transformers/models/gemma/modeling_gemma.py:652, in GemmaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position)
#     650 residual = hidden_states
#     651 hidden_states = self.post_attention_layernorm(hidden_states)
# --> 652 hidden_states = self.mlp(hidden_states)
#     653 hidden_states = residual + hidden_states
#     655 outputs = (hidden_states,)
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/transformers/models/gemma/modeling_gemma.py:185, in GemmaMLP.forward(self, x)
#     184 def forward(self, x):
# --> 185     return self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/webIR2024/.venv/lib/python3.11/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
print(tokenizer.decode(outputs[0]))
# Out:
# <bos>How to change file permissions in Unix?
#
# <h2>How do I set the permission of a directory on Linux?</h2>
#
# To give all users read and write access, use chmod 755. To make it so that only root can delete files or directories but everyone else has full rights for reading them: Use chmod 640 (or just u+rwx). This will allow you as user “root” remove any other folder/file than your own without having problems with others deleting yours accidentally! The last number is what

# %%
from mlx_lm import load, generate

model, tokenizer = load("mlx-community/quantized-gemma-7b-it")
response = generate(model, tokenizer, prompt="hello", verbose=True)
